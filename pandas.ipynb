# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

pd.__version__
# Out:
# '2.2.3'

# %%
a = pd.Series([45,40,42,43,41,23])
print(a)
print(type(a))
# Out:
# 0    45
# 1    40
# 2    42
# 3    43
# 4    41
# 5    23
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd

a = pd.Series([45,40,42,43,41,23], index = [1,2,3,4.5,6])
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 a = pd.Series([45,40,42,43,41,23], index = [1,2,3,4.5,6])
#       4 print(a)
#
# File c:\Python312\Lib\site-packages\pandas\core\series.py:575, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     573     index = default_index(len(data))
#     574 elif is_list_like(data):
# --> 575     com.require_length_match(data, index)
#     577 # create/copy the manager
#     578 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File c:\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
# ...

# %%
import pandas as pd
a = pd.Series([45,40,42,43,41,23], dtype="bool")
print(a)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# dtype: bool

# %%
import pandas as pd
a = pd.Series([45,40,42,43,41,23], dtype="float")
print(a)
# Out:
# 0    45.0
# 1    40.0
# 2    42.0
# 3    43.0
# 4    41.0
# 5    23.0
# dtype: float64

# %%
a = ["math", "physics", "chemistry"]
b= [28,29,25]
c = pd.Series(b, index = a,dtype="float")
print(c)
len(c)
# Out:
# math         28.0
# physics      29.0
# chemistry    25.0
# dtype: float64
# 3

# %%
a = pd.Series([45,40,42,43,41,23],index = [1,2,3,4,5,6],name = "sk")
print(a)
# Out:
# 1    45
# 2    40
# 3    42
# 4    43
# 5    41
# 6    23
# Name: sk, dtype: int64

# %%
x = []
for var in range(1,3001):
    x.append(var)

a = pd.Series(x)
print(a)
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2995    2996
# 2996    2997
# 2997    2998
# 2998    2999
# 2999    3000
# Length: 3000, dtype: int64

# %%
a = pd.Series([45,40,42,43,41,23])
print(a)
# Out:
# 0    45
# 1    40
# 2    42
# 3    43
# 4    41
# 5    23
# dtype: int64

# %%
a > 40
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
min(a)
# Out:
# 23

# %%
max(a)
# Out:
# 45

# %%
pf = pd.DataFrame({'math':[28,26,24],'science':[2,26,28],'englaish': [24,20,18]})
print(pf)
# Out:
#    math  science  englaish
# 0    28        2        24
# 1    26       26        20
# 2    24       28        18

# %%
i = ["shashank","saurabh","sachin"]
p = pd.Series([160,125,150],index = i)
q = pd.Series([55,66,48],index = i)
df = pd.DataFrame({"height":p,"weight":q})
print(df)
# Out:
#           height  weight
# shashank     160      55
# saurabh      125      66
# sachin       150      48

# %%
import pandas as pd

path = r"D:\Data Science\Reading Material\pandas\Movieratingdata.csv"

# %%
df = pd.read_csv(path)
print(df.head())
# Out:
#    USER_ID MOVIE_ID    MOVIE_TITLE  PRODUCTION_YEAR  RATING
# 0        1        a        Holiday             2015       8
# 1        2        b        Holiday             2016       6
# 2        3        b         Spyder             2020       8
# 3        4        b          Krish             2020       5
# 4        5        c  Koyi mil gaya             2019       4

# %%
df.columns
# Out:
# Index(['USER_ID', 'MOVIE_ID', 'MOVIE_TITLE', 'PRODUCTION_YEAR', 'RATING'], dtype='object')

# %%
df.dtypes
# Out:
# USER_ID             int64
# MOVIE_ID           object
# MOVIE_TITLE        object
# PRODUCTION_YEAR     int64
# RATING              int64
# dtype: object

# %%
df["USER_ID"] = df["USER_ID"].astype(float)

# %%
df
# Out:
#    USER_ID MOVIE_ID    MOVIE_TITLE  PRODUCTION_YEAR  RATING
# 0      1.0        a        Holiday             2015       8
# 1      2.0        b        Holiday             2016       6
# 2      3.0        b         Spyder             2020       8
# 3      4.0        b          Krish             2020       5
# 4      5.0        c  Koyi mil gaya             2019       4
# 5      6.0        d  Koyi mil gaya             2020       5
# 6      7.0        d         Spyder             2015       9
# 7      8.0        e   Man in Black             2006       9
# 8      9.0        f         Spyder             2015      10
# 9     10.0        g   Man in Black             2015       9

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv(path, dtype = {"MovIE_ID":float,"PRODUCTION_YEAR":float})
print(df.head())
# Out:
#    USER_ID MOVIE_ID    MOVIE_TITLE  PRODUCTION_YEAR  RATING
# 0        1        a        Holiday           2015.0       8
# 1        2        b        Holiday           2016.0       6
# 2        3        b         Spyder           2020.0       8
# 3        4        b          Krish           2020.0       5
# 4        5        c  Koyi mil gaya           2019.0       4

# %%
import pandas as pd

path = r"D:\Data Science\dataset\Movieratingdata.csv"

# %%
df = pd.read_csv(path)
print(df.head())
# Out:
#    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1   4642044                     Riot              2015
# 1        2   1925518          The Protector 2              2013
# 2        3    372784            Batman Begins              2005
# 3        4   1390411  In the Heart of the Sea              2015
# 4        5   6306064                   Adrift              2018
#
#                                               GENRES  RATING  Unnamed: 6  \
# 0                                             Action     8.0         NaN
# 1                                             Action     5.0         NaN
# 2                                   Action|Adventure     9.0         NaN
# 3  Action|Adventure|Biography|Drama|History|Thriller     5.0         NaN
# 4  Action|Adventure|Biography|Drama|Romance|Thriller     4.0         NaN
#
#    Unnamed: 7    GENRES.1  Unnamed: 9
# 0         1.0      action         8.0
# 1         5.0    suspense         6.0
# ...

# %%
df["USER_ID"] = df["USER_ID"].astype(float)

# %%
df = pd.read_csv(path, dtype = {"MovIE_ID":float,"PRODUCTION_YEAR":float})
print(df.head())
# Out:
#    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1   4642044                     Riot            2015.0
# 1        2   1925518          The Protector 2            2013.0
# 2        3    372784            Batman Begins            2005.0
# 3        4   1390411  In the Heart of the Sea            2015.0
# 4        5   6306064                   Adrift            2018.0
#
#                                               GENRES  RATING  Unnamed: 6  \
# 0                                             Action     8.0         NaN
# 1                                             Action     5.0         NaN
# 2                                   Action|Adventure     9.0         NaN
# 3  Action|Adventure|Biography|Drama|History|Thriller     5.0         NaN
# 4  Action|Adventure|Biography|Drama|Romance|Thriller     4.0         NaN
#
#    Unnamed: 7    GENRES.1  Unnamed: 9
# 0         1.0      action         8.0
# 1         5.0    suspense         6.0
# ...

# %%
df = pd.read_csv(path, dtype = {"MovIE_ID":"float64","PRODUCTION_YEAR":"float64","USER_ID":"float64"})
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1.0   4642044                     Riot            2015.0
# 1        2.0   1925518          The Protector 2            2013.0
# 2        3.0    372784            Batman Begins            2005.0
# 3        4.0   1390411  In the Heart of the Sea            2015.0
# 4        5.0   6306064                   Adrift            2018.0
# ..       ...       ...                       ...              ...
# 495    496.0   1846589            Hunter Killer            2018.0
# 496    497.0   4196776             Jason Bourne            2016.0
# 497    498.0   7456310                     Anna            2019.0
# 498    499.0   8106534            6 Underground            2019.0
# 499    500.0   2302755       Olympus Has Fallen            2013.0
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %% [markdown]
# 10 - 02 - 2025

# %%
df = pd.read_csv(path,nrows = 5)
df
# Out:
#    USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        1   4642044                     Riot              2015
# 1        2   1925518          The Protector 2              2013
# 2        3    372784            Batman Begins              2005
# 3        4   1390411  In the Heart of the Sea              2015
# 4        5   6306064                   Adrift              2018
#
#                                               GENRES  RATING  Unnamed: 6  \
# 0                                             Action       8         NaN
# 1                                             Action       5         NaN
# 2                                   Action|Adventure       9         NaN
# 3  Action|Adventure|Biography|Drama|History|Thriller       5         NaN
# 4  Action|Adventure|Biography|Drama|Romance|Thriller       4         NaN
#
#    Unnamed: 7    GENRES.1  Unnamed: 9
# 0         1.0      action         8.0
# 1         5.0    suspense         6.0
# ...

# %%
df = pd.read_csv(path,skiprows= 5)
df
# Out:
#        5  6306064              Adrift   2018  \
# 0      6  6306064              Adrift   2018
# 1      7  2719848             Everest   2015
# 2      8   462504         Rescue Dawn   2006
# 3      9  1663202        The Revenant   2015
# 4     10  1663202        The Revenant   2015
# ..   ...      ...                  ...   ...
# 490  496  1846589       Hunter Killer   2018
# 491  497  4196776        Jason Bourne   2016
# 492  498  7456310                Anna   2019
# 493  499  8106534       6 Underground   2019
# 494  500  2302755  Olympus Has Fallen   2013
#
#      Action|Adventure|Biography|Drama|Romance|Thriller     4  Unnamed: 6  \
# 0    Action|Adventure|Biography|Drama|Romance|Thriller   5.0         NaN
# 1            Action|Adventure|Biography|Drama|Thriller   6.0         NaN
# 2                 Action|Adventure|Biography|Drama|War   8.0         NaN
# 3             Action|Adventure|Biography|Drama|Western  10.0         NaN
# ...

# %%
df = pd.read_csv(path,skiprows = [1,3,7,10,11])
df
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          2   1925518          The Protector 2              2013
# 1          4   1390411  In the Heart of the Sea              2015
# 2          5   6306064                   Adrift              2018
# 3          6   6306064                   Adrift              2018
# 4          8    462504              Rescue Dawn              2006
# ..       ...       ...                       ...              ...
# 490      496   1846589            Hunter Killer              2018
# 491      497   4196776             Jason Bourne              2016
# 492      498   7456310                     Anna              2019
# 493      499   8106534            6 Underground              2019
# 494      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action       5         NaN
# ...

# %%
df = pd.read_csv(path, usecols =["MOVIE_TITLE"])
df
# Out:
#                   MOVIE_TITLE
# 0                       Riot
# 1            The Protector 2
# 2              Batman Begins
# 3    In the Heart of the Sea
# 4                     Adrift
# ..                        ...
# 495            Hunter Killer
# 496             Jason Bourne
# 497                     Anna
# 498            6 Underground
# 499       Olympus Has Fallen
#
# [500 rows x 1 columns]

# %%
df = pd.read_csv(path, usecols =["MOVIE_TITLE","PRODUCTION_YEAR","RATING"])
df
# Out:
#                   MOVIE_TITLE  PRODUCTION_YEAR  RATING
# 0                       Riot              2015     8.0
# 1            The Protector 2              2013     5.0
# 2              Batman Begins              2005     9.0
# 3    In the Heart of the Sea              2015     5.0
# 4                     Adrift              2018     4.0
# ..                        ...              ...     ...
# 495            Hunter Killer              2018     6.0
# 496             Jason Bourne              2016     6.0
# 497                     Anna              2019     7.0
# 498            6 Underground              2019     4.0
# 499       Olympus Has Fallen              2013     1.0
#
# [500 rows x 3 columns]

# %%
df = pd.read_csv(path, usecols =[0,3,5])
df
# Out:
#      USER_ID  PRODUCTION_YEAR  RATING
# 0          1             2015     8.0
# 1          2             2013     5.0
# 2          3             2005     9.0
# 3          4             2015     5.0
# 4          5             2018     4.0
# ..       ...              ...     ...
# 495      496             2018     6.0
# 496      497             2016     6.0
# 497      498             2019     7.0
# 498      499             2019     4.0
# 499      500             2013     1.0
#
# [500 rows x 3 columns]

# %%
df = pd.read_csv(path, index_col=["USER_ID"])
df
# Out:
#          MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# USER_ID
# 1         4642044                     Riot              2015
# 2         1925518          The Protector 2              2013
# 3          372784            Batman Begins              2005
# 4         1390411  In the Heart of the Sea              2015
# 5         6306064                   Adrift              2018
# ...           ...                       ...              ...
# 496       1846589            Hunter Killer              2018
# 497       4196776             Jason Bourne              2016
# 498       7456310                     Anna              2019
# 499       8106534            6 Underground              2019
# 500       2302755       Olympus Has Fallen              2013
#
#                                                     GENRES  RATING  \
# USER_ID
# 1                                                   Action     8.0
# 2                                                   Action     5.0
# ...

# %%
df.columns
# Out:
# Index(['MOVIE_ID', 'MOVIE_TITLE', 'PRODUCTION_YEAR', 'GENRES', 'RATING',
#        'Unnamed: 6', 'Unnamed: 7', 'GENRES.1', 'Unnamed: 9'],
#       dtype='object')

# %%
df.reset_index(inplace=True)
df
# Out:
#      index  USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0        0        1   4642044                     Riot              2015
# 1        1        2   1925518          The Protector 2              2013
# 2        2        3    372784            Batman Begins              2005
# 3        3        4   1390411  In the Heart of the Sea              2015
# 4        4        5   6306064                   Adrift              2018
# ..     ...      ...       ...                       ...              ...
# 495    495      496   1846589            Hunter Killer              2018
# 496    496      497   4196776             Jason Bourne              2016
# 497    497      498   7456310                     Anna              2019
# 498    498      499   8106534            6 Underground              2019
# 499    499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# ...

# %%
df = pd.read_csv(path,index_col = ["PRODUCTION_YEAR"])
df
# Out:
#                  USER_ID  MOVIE_ID               MOVIE_TITLE  \
# PRODUCTION_YEAR
# 2015                   1   4642044                     Riot
# 2013                   2   1925518          The Protector 2
# 2005                   3    372784            Batman Begins
# 2015                   4   1390411  In the Heart of the Sea
# 2018                   5   6306064                   Adrift
# ...                  ...       ...                       ...
# 2018                 496   1846589            Hunter Killer
# 2016                 497   4196776             Jason Bourne
# 2019                 498   7456310                     Anna
# 2019                 499   8106534            6 Underground
# 2013                 500   2302755       Olympus Has Fallen
#
#                                                             GENRES  RATING  \
# PRODUCTION_YEAR
# 2015                                                        Action     8.0
# ...

# %%
df = pd.read_csv(path,index_col = ["PRODUCTION_YEAR"])
df.sort_index()
# Out:
#                  USER_ID  MOVIE_ID                       MOVIE_TITLE  \
# PRODUCTION_YEAR
# 1967                 255     61418                 Bonnie and Clyde
# 1969                 236     64757  On Her Majesty's Secret Service
# 1972                 365     69121                        Prime Cut
# 1973                 484     70909                        Westworld
# 1974                 237     71807      The Man with the Golden Gun
# ...                  ...       ...                               ...
# 2019                 206   4154664                   Captain Marvel
# 2019                 208   6565702                     Dark Phoenix
# 2019                 211   4154664                   Captain Marvel
# 2019                 156   6565702                     Dark Phoenix
# 2019                 142   5886046                      Escape Room
#
#                                                    GENRES  RATING  Unnamed: 6  \
# PRODUCTION_YEAR
# ...

# %%
df.sort_index(ascending=False, inplace=True)
df
# Out:
#                  USER_ID  MOVIE_ID                       MOVIE_TITLE  \
# PRODUCTION_YEAR
# 2019                 142   5886046                      Escape Room
# 2019                 325   8367814                    The Gentlemen
# 2019                 149   8364368                            Crawl
# 2019                 498   7456310                             Anna
# 2019                  68   1488606                  Triple Frontier
# ...                  ...       ...                               ...
# 1974                 237     71807      The Man with the Golden Gun
# 1973                 484     70909                        Westworld
# 1972                 365     69121                        Prime Cut
# 1969                 236     64757  On Her Majesty's Secret Service
# 1967                 255     61418                 Bonnie and Clyde
#
#                                                    GENRES  RATING  Unnamed: 6  \
# PRODUCTION_YEAR
# ...

# %%
df1 = pd.read_csv(r"D:\Data Science\dataset\Movieratingdata.csv")
df1
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %%
df1 = pd.read_csv(r"D:\Data Science\dataset\Movieratingdata.csv")
df1 = df1.add_prefix("data")
df1
# Out:
#      dataUSER_ID  dataMOVIE_ID           dataMOVIE_TITLE  dataPRODUCTION_YEAR  \
# 0              1       4642044                     Riot                  2015
# 1              2       1925518          The Protector 2                  2013
# 2              3        372784            Batman Begins                  2005
# 3              4       1390411  In the Heart of the Sea                  2015
# 4              5       6306064                   Adrift                  2018
# ..           ...           ...                       ...                  ...
# 495          496       1846589            Hunter Killer                  2018
# 496          497       4196776             Jason Bourne                  2016
# 497          498       7456310                     Anna                  2019
# 498          499       8106534            6 Underground                  2019
# 499          500       2302755       Olympus Has Fallen                  2013
#
# ...

# %%
df1 = pd.read_csv(r"D:\Data Science\dataset\Movieratingdata.csv")
df1
# Out:
#      USER_ID  MOVIE_ID               MOVIE_TITLE  PRODUCTION_YEAR  \
# 0          1   4642044                     Riot              2015
# 1          2   1925518          The Protector 2              2013
# 2          3    372784            Batman Begins              2005
# 3          4   1390411  In the Heart of the Sea              2015
# 4          5   6306064                   Adrift              2018
# ..       ...       ...                       ...              ...
# 495      496   1846589            Hunter Killer              2018
# 496      497   4196776             Jason Bourne              2016
# 497      498   7456310                     Anna              2019
# 498      499   8106534            6 Underground              2019
# 499      500   2302755       Olympus Has Fallen              2013
#
#                                                 GENRES  RATING  Unnamed: 6  \
# 0                                               Action     8.0         NaN
# ...

# %%
df.head()
# Out:
#                  USER_ID  MOVIE_ID               MOVIE_TITLE  \
# PRODUCTION_YEAR
# 2015                   1   4642044                     Riot
# 2013                   2   1925518          The Protector 2
# 2005                   3    372784            Batman Begins
# 2015                   4   1390411  In the Heart of the Sea
# 2018                   5   6306064                   Adrift
#
#                                                             GENRES  RATING  \
# PRODUCTION_YEAR
# 2015                                                        Action     8.0
# 2013                                                        Action     5.0
# 2005                                              Action|Adventure     9.0
# 2015             Action|Adventure|Biography|Drama|History|Thriller     5.0
# 2018             Action|Adventure|Biography|Drama|Romance|Thriller     4.0
#
#                  Unnamed: 6  Unnamed: 7    GENRES.1  Unnamed: 9
# PRODUCTION_YEAR
# ...

# %%
df.head(60) # Display the first 60 rows of the DataFrame
# Out:
#           0         1                                      2                3  \
# 0   USER_ID  MOVIE_ID                            MOVIE_TITLE  PRODUCTION_YEAR
# 1         1   4642044                                  Riot              2015
# 2         2   1925518                       The Protector 2              2013
# 3         3    372784                         Batman Begins              2005
# 4         4   1390411               In the Heart of the Sea              2015
# 5         5   6306064                                Adrift              2018
# 6         6   6306064                                Adrift              2018
# 7         7   2719848                               Everest              2015
# 8         8    462504                           Rescue Dawn              2006
# 9         9   1663202                          The Revenant              2015
# 10       10   1663202                          The Revenant              2015
# ...

# %%
df.tail #
# Out:
# <bound method NDFrame.tail of                  USER_ID  MOVIE_ID               MOVIE_TITLE  \
# PRODUCTION_YEAR
# 2015                   1   4642044                     Riot
# 2013                   2   1925518          The Protector 2
# 2005                   3    372784            Batman Begins
# 2015                   4   1390411  In the Heart of the Sea
# 2018                   5   6306064                   Adrift
# ...                  ...       ...                       ...
# 2018                 496   1846589            Hunter Killer
# 2016                 497   4196776             Jason Bourne
# 2019                 498   7456310                     Anna
# 2019                 499   8106534            6 Underground
# 2013                 500   2302755       Olympus Has Fallen
#
#                                                             GENRES  RATING  \
# PRODUCTION_YEAR
# 2015                                                        Action     8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       501 non-null    object
#  1   1       501 non-null    object
#  2   2       501 non-null    object
#  3   3       501 non-null    object
#  4   4       501 non-null    object
#  5   5       501 non-null    object
#  6   6       0 non-null      float64
#  7   7       2 non-null      float64
#  8   8       6 non-null      object
#  9   9       4 non-null      float64
# dtypes: float64(3), object(7)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#          6         7         9
# count  0.0  2.000000  4.000000
# mean   NaN  3.000000  5.750000
# std    NaN  2.828427  1.707825
# min    NaN  1.000000  4.000000
# 25%    NaN  2.000000  4.750000
# 50%    NaN  3.000000  5.500000
# 75%    NaN  4.000000  6.500000
# max    NaN  5.000000  8.000000

# %%
df.shape
# Out:
# (501, 10)

# %%
df.shape[0]
# Out:
# 501

# %%
df.size
# Out:
# 5010

# %%
df.sample()
# Out:
#        0        1                 2     3                           4  5   6  \
# 267  267  2179136  American Sniper   2014  Action|Biography|Drama|War  7 NaN
#
#       7    8   9
# 267 NaN  NaN NaN

# %%
df.loc[1:10,1]
df1
# Out:
#      dataUSER_ID  dataMOVIE_ID           dataMOVIE_TITLE  dataPRODUCTION_YEAR  \
# 0              1       4642044                     Riot                  2015
# 1              2       1925518          The Protector 2                  2013
# 2              3        372784            Batman Begins                  2005
# 3              4       1390411  In the Heart of the Sea                  2015
# 4              5       6306064                   Adrift                  2018
# ..           ...           ...                       ...                  ...
# 495          496       1846589            Hunter Killer                  2018
# 496          497       4196776             Jason Bourne                  2016
# 497          498       7456310                     Anna                  2019
# 498          499       8106534            6 Underground                  2019
# 499          500       2302755       Olympus Has Fallen                  2013
#
# ...
